# %%
import pandas as pd
import numpy as np
import requests
import json

url = "https://spaceflightnewsapi.net/api/v1/articles?search=spacex"

# %%
request = requests.get(url)

# %%
req = request.json()
req
# Out:
# {'docs': [{'date_published': 1598675078,
#    'date_added': 1598675198,
#    'tags': ['lab',
#     'launch',
#     'launches',
#     'heavy',
#     'mission',
#     'weather',
#     'flight',
#     'spacex',
#     'rocket',
#     'ula',
#     'weekend',
#     'attempt',
#     'planned'],
#    'categories': [],
#    'featured': False,
#    'launches': [],
#    'events': [],
#    'll': [],
#    '_id': '5f49d8feb19b5c530b2bc216',
#    'news_site': 'teslarati',
#    'news_site_long': 'Teslarati',
#    'title': 'SpaceX, Rocket Lab, ULA all have rocket launches planned this weekend',
#    'url': 'https://www.teslarati.com/spacex-rocket-lab-ula-all-have-rocket-launches-planned-this-weekend/',
#    'id': '',
#    'featured_image': 'https://www.teslarati.com/wp-content/uploads/2020/08/Banner1.jpg',
#    'published_date': '2020-08-29T04:24:38.000Z',
#    'imported_date': '2020-08-29T04:26:38.000Z'},
#   {'date_published': 1598604900,
#    'date_added': 1598604993,
#    'tags': ['falcon',
# ...
